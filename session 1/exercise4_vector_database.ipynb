# %% [markdown]
# # Exercise: Using Chroma as a Vector Database
#
# In this exercise, you will learn how to store and retrieve text embeddings using Chroma, a powerful open-source vector database.
# We will perform basic text embedding storage and retrieval, utilizing LangChain's integration with Chroma.

# %%
# Install necessary packages
# !pip install langchain chromadb tiktoken openai langchain-community
# Out:
# Requirement already satisfied: langchain in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (0.3.17)
# Requirement already satisfied: chromadb in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (0.6.3)
# Requirement already satisfied: tiktoken in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (0.8.0)
# Requirement already satisfied: openai in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (1.60.2)
# Requirement already satisfied: langchain-community in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (0.3.16)
# Requirement already satisfied: PyYAML>=5.3 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.33 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (0.3.33)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (0.3.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (1.24.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (2.10.6)
# Requirement already satisfied: requests<3,>=2 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain) (8.2.3)
# Requirement already satisfied: build>=1.0.3 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (0.115.8)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (3.11.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (0.21.0)
# Requirement already satisfied: pypika>=0.48.9 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (7.6.0)
# Requirement already satisfied: importlib-resources in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (1.70.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (32.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from chromadb) (13.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from openai) (0.8.2)
# Requirement already satisfied: sniffio in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain-community) (2.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: packaging>=19.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: pyproject_hooks in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.45.3)
# Requirement already satisfied: certifi in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.1.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.33->langchain) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (25.1.24)
# Requirement already satisfied: protobuf in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.17.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.28.1)
# Requirement already satisfied: click>=8.0.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.12.0)
# Requirement already satisfied: zipp>=0.5 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.33->langchain) (2.4)
# Requirement already satisfied: mdurl~=0.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/Davy/Library/Caches/pypoetry/virtualenvs/davy-PIAAdT6P-py3.11/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
#
# [notice] A new release of pip is available: 23.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 1. Import Required Libraries
# Import the necessary classes from LangChain, Chroma, and OpenAI.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.embeddings.openai import OpenAIEmbeddings
import os

# %%
# Set up OpenAI API Key
os.environ["OPENAI_API_KEY"] = "<api key>"

# %% [markdown]
# ## 2. Text Splitting
# Since large texts may not be efficiently stored and queried, we will use a text splitter to break the text into smaller chunks.

# %%
# Sample text to store
text = """
Vector databases like Chroma enable efficient semantic search by storing and managing high-dimensional vector embeddings. Unlike traditional keyword-based search, which relies on exact matches, semantic search retrieves data based on conceptual similarity, making it highly valuable in various AI and machine learning applications.

What Makes Vector Databases Powerful?

Vector databases store numerical representations (embeddings) of text, images, or other types of data. These embeddings capture the meaning and context of the data, allowing for fuzzy matching and contextual retrieval instead of relying solely on exact terms. This enables a more intuitive and relevant search experience across different domains.

For example, in natural language processing (NLP), a traditional search for “AI development” might return only documents containing that exact phrase. However, a vector search could retrieve documents discussing machine learning, neural networks, and deep learning, since these concepts are semantically related.

Use Cases of Chroma in AI-Powered Applications
	1.	Retrieval-Augmented Generation (RAG)
	•	Chroma plays a crucial role in enhancing Large Language Models (LLMs) by allowing them to fetch relevant external knowledge before generating responses.
	•	Instead of relying solely on pre-trained knowledge, models can retrieve real-time or domain-specific data to produce more accurate and up-to-date answers.
	•	Example: A legal AI assistant could use Chroma to search legal documents semantically rather than relying on strict keyword matches.
	2.	Recommendation Systems
	•	Chroma can improve recommendation algorithms by comparing user preferences with product embeddings.
	•	Instead of exact-item matching, vector search recommends conceptually similar products.
	•	Example: A movie streaming service can suggest films with similar themes, moods, or actors rather than only matching by genre.
	3.	Anomaly Detection
	•	Chroma helps detect patterns that deviate from normal behavior in industries like cybersecurity, fraud prevention, and predictive maintenance.
	•	Example: A financial institution can use Chroma to analyze transaction embeddings and identify fraudulent activities that don’t follow typical spending patterns.
	4.	Medical and Scientific Research
	•	In healthcare, vector databases assist in clinical decision support, where patient records are searched semantically.
	•	Example: A doctor searching for “rare autoimmune disorder” might retrieve cases related to similar symptoms and conditions even if the exact disease name is not mentioned.
	5.	Image and Video Similarity Search
	•	Vector embeddings allow searching for images based on content rather than file names or tags.
	•	Example: An e-commerce platform can let users upload a product image to find visually similar products without relying on manual tagging.
	6.	Chatbots and Conversational AI
	•	By storing and retrieving conversation history and external knowledge, Chroma enhances memory retention in AI-powered chat systems.
	•	Example: A customer service bot can retrieve previous interactions and related FAQs to provide personalized responses.
	7.	Real-Time Data Indexing
	•	Many traditional databases require periodic indexing, whereas Chroma supports real-time updates.
	•	This ensures that the latest information is immediately available for retrieval.
	•	Example: News aggregation platforms use vector search to provide contextually relevant articles as soon as they are published.

Why Chroma Over Other Vector Databases?

While there are multiple vector databases, Chroma stands out due to its ease of integration, efficiency, and support for real-time data retrieval. It is designed with a developer-friendly approach, making it ideal for scalable AI applications.
	•	Pinecone is a great alternative for fully managed vector search but may lack customization flexibility.
	•	FAISS (Facebook AI Similarity Search) is highly optimized for similarity search but requires more engineering effort to deploy.
	•	Milvus provides a strong open-source alternative for high-scale similarity search.
	•	Weaviate and Qdrant are other notable options with strong graph-based reasoning and search optimizations.

Conclusion: The Future of AI-Driven Search with Chroma

Chroma’s vector-based approach to search, recommendation, and retrieval is revolutionizing how businesses use AI. It enables more intuitive interactions, reduces manual tagging requirements, and improves AI decision-making capabilities across industries.

As AI and machine learning evolve, vector databases will become essential for building intelligent, context-aware applications, bridging the gap between static knowledge and real-time adaptive AI systems.
"""
# Split text into chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=10)
text_chunks = text_splitter.split_text(text)

print(f"Text split into {len(text_chunks)} chunks:")
for chunk in text_chunks:
    print(chunk)
# Out:
# Text split into 125 chunks:
# Vector databases like Chroma enable efficient
# efficient semantic search by storing and managing
# managing high-dimensional vector embeddings.
# Unlike traditional keyword-based search, which
# which relies on exact matches, semantic search
# search retrieves data based on conceptual
# similarity, making it highly valuable in various
# various AI and machine learning applications.
# What Makes Vector Databases Powerful?
# Vector databases store numerical representations
# (embeddings) of text, images, or other types of
# types of data. These embeddings capture the
# the meaning and context of the data, allowing for
# for fuzzy matching and contextual retrieval
# retrieval instead of relying solely on exact
# on exact terms. This enables a more intuitive and
# and relevant search experience across different
# different domains.
# For example, in natural language processing
# (NLP), a traditional search for “AI development”
# might return only documents containing that exact
# exact phrase. However, a vector search could
# could retrieve documents discussing machine
# machine learning, neural networks, and deep
# and deep learning, since these concepts are
# are semantically related.
# Use Cases of Chroma in AI-Powered Applications
# 1.	Retrieval-Augmented Generation (RAG)
# •	Chroma plays a crucial role in enhancing Large
# Large Language Models (LLMs) by allowing them to
# them to fetch relevant external knowledge before
# before generating responses.
# •	Instead of relying solely on pre-trained
# knowledge, models can retrieve real-time or
# or domain-specific data to produce more accurate
# accurate and up-to-date answers.
# •	Example: A legal AI assistant could use Chroma
# Chroma to search legal documents semantically
# rather than relying on strict keyword matches.
# 2.	Recommendation Systems
# •	Chroma can improve recommendation algorithms
# by comparing user preferences with product
# product embeddings.
# •	Instead of exact-item matching, vector search
# search recommends conceptually similar products.
# •	Example: A movie streaming service can suggest
# suggest films with similar themes, moods, or
# moods, or actors rather than only matching by
# by genre.
# 3.	Anomaly Detection
# •	Chroma helps detect patterns that deviate from
# from normal behavior in industries like
# like cybersecurity, fraud prevention, and
# and predictive maintenance.
# •	Example: A financial institution can use
# can use Chroma to analyze transaction embeddings
# and identify fraudulent activities that don’t
# don’t follow typical spending patterns.
# 4.	Medical and Scientific Research
# •	In healthcare, vector databases assist in
# assist in clinical decision support, where
# where patient records are searched semantically.
# •	Example: A doctor searching for “rare
# for “rare autoimmune disorder” might retrieve
# retrieve cases related to similar symptoms and
# and conditions even if the exact disease name is
# name is not mentioned.
# 5.	Image and Video Similarity Search
# •	Vector embeddings allow searching for images
# images based on content rather than file names or
# names or tags.
# •	Example: An e-commerce platform can let users
# let users upload a product image to find visually
# visually similar products without relying on
# on manual tagging.
# 6.	Chatbots and Conversational AI
# •	By storing and retrieving conversation history
# history and external knowledge, Chroma enhances
# enhances memory retention in AI-powered chat
# chat systems.
# •	Example: A customer service bot can retrieve
# retrieve previous interactions and related FAQs
# FAQs to provide personalized responses.
# 7.	Real-Time Data Indexing
# •	Many traditional databases require periodic
# periodic indexing, whereas Chroma supports
# supports real-time updates.
# •	This ensures that the latest information is
# is immediately available for retrieval.
# •	Example: News aggregation platforms use vector
# vector search to provide contextually relevant
# relevant articles as soon as they are published.
# Why Chroma Over Other Vector Databases?
# While there are multiple vector databases, Chroma
# Chroma stands out due to its ease of integration,
# efficiency, and support for real-time data
# data retrieval. It is designed with a
# with a developer-friendly approach, making it
# making it ideal for scalable AI applications.
# •	Pinecone is a great alternative for fully
# for fully managed vector search but may lack
# may lack customization flexibility.
# •	FAISS (Facebook AI Similarity Search) is
# is highly optimized for similarity search but
# but requires more engineering effort to deploy.
# •	Milvus provides a strong open-source
# alternative for high-scale similarity search.
# •	Weaviate and Qdrant are other notable options
# options with strong graph-based reasoning and
# and search optimizations.
# Conclusion: The Future of AI-Driven Search with
# with Chroma
# Chroma’s vector-based approach to search,
# search, recommendation, and retrieval is
# is revolutionizing how businesses use AI. It
# AI. It enables more intuitive interactions,
# reduces manual tagging requirements, and improves
# improves AI decision-making capabilities across
# across industries.
# As AI and machine learning evolve, vector
# vector databases will become essential for
# for building intelligent, context-aware
# applications, bridging the gap between static
# static knowledge and real-time adaptive AI
# AI systems.

# %% [markdown]
# ## 3. Storing and Retrieving Embeddings with Chroma
# We will now store the embeddings in Chroma and perform a similarity search.

# %%
# Initialize OpenAI Embeddings
embeddings = OpenAIEmbeddings()

# Store text chunks in Chroma
# we dont persist the vector store in this exercise, in production you would

vector_store = Chroma.from_texts(texts=text_chunks, embedding=embeddings) 
# Perform a similarity search
query = "chroma database"
results = vector_store.similarity_search(query, k=2)

print("Top matching text chunks:")
for res in results:
    print(res.page_content)
# Out:
# Top matching text chunks:
# While there are multiple vector databases, Chroma
# with Chroma

# %% [markdown]
# ## 4. Assignment: Extend the Vector Search
# Modify the script to:
# 1. Load a larger text document and split it into chunks.
# 2. Store the embeddings in Chroma.
# 3. Perform similarity searches with different queries.
# 4. Try adjusting the chunk size and observe the impact on retrieval.
#
# research multiple text splitting methods in the langchain documentation. Use the text FDA as an example of a source of knowledge. Your goal is that for every question, you find the passages in the text that are relevant for it.
